# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyasr957-gif/Training-program/blob/main/UntitledPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("enter no. of monkeys"))
k=int(input("enter no. of bananas a monkey can eat"))
j=int(input("enter no. of peanut a monkey can eat"))
m=int(input("total no. of bananas"))
p=int(input("total number of peanuts"))
if k<0 or j<0:
      print("invalid input")
noofmonkeys=m//k+p//j
n=n-noofmonkeys
if m%k!=0 or p%j!=0:
      n=n-1
print(n)
# Out:
# enter no. of monkeys20
# enter no. of bananas a monkey can eat2
# enter no. of peanut a monkey can eat3
# total no. of bananas12
# total number of peanuts12
# 10

# %%
print("using temp")
p=int(input("Enter first number:"))
q=int(input("Enter second number"))
print(p,q)
temp=p
p=q
q=temp
print(p,q)
print("using ,")
p=int(input("Enter first number:"))
q=int(input("Enter second number"))
print(p,q)
p,q=q,p
print(p,q)
print("using +/-")
p=int(input("Enter first number:"))
q=int(input("Enter second number"))
print(p,q)
p=p+q
q=p-q
p=p-q
print(p,q)
print("using ^")
p=int(input("Enter first number:"))
q=int(input("Enter second number"))
print(p,q)
p=p^q
q=p^q
p=p^q
print(p,q)
# Out:
# using temp
# Enter first number:12
# Enter second number33
# 12 33
# 33 12
# using ,
# Enter first number:11
# Enter second number22
# 11 22
# 22 11
# using +/-
# Enter first number:55
# Enter second number34
# 55 34
# 34 55
# using ^
# Enter first number:45
# Enter second number87
# 45 87
# 87 45

# %%
n=int(input("Enter jar capacity:"))
k=int(input("Enter min candies:"))
t=n
i='y'
ts=0
while i!='n':
  x=int(input("Enter candies to sold:"))
  if x>n:
    print("Invalid input")
  else:
    n=n-x
    ts=ts+x
    print("Sold:",x)
    if n<=k:
      n=t
    print("Available candies:",n)
    print("Total sold",ts)
# Out:
# Enter jar capacity:10
# Enter min candies:5
# Enter candies to sold:3
# Sold: 3
# Available candies: 7
# Total sold 3
# Enter candies to sold:3
# Sold: 3
# Available candies: 10
# Total sold 6
# Enter candies to sold:3
# Sold: 3
# Available candies: 7
# Total sold 9
# Enter candies to sold:3
# Sold: 3
# Available candies: 10
# Total sold 12
# Enter candies to sold:3
# Sold: 3
# Available candies: 7
# Total sold 15
# Enter candies to sold:3
# Sold: 3
# Available candies: 10
# Total sold 18
